# %% [markdown]
# # Import Libraries

# %%
import glob, os                           # Python standard library
import sys                                # Python standard library
# -------------------------------------------- convert .XLSX to .XML files
import xlrd                               # NEED to be installed
# -------------------------------------------- API
import requests                           # NEED to be installed

# %% [markdown]
# # Set Input and Output File Roots

# %%
# Read in file (need to be changed if to read new document)
excel_file_path = r"C:/Users/gnt5/Documents/WebFF/xlsx/WebFF-Class I-DataTemplate-24May17.xlsx"
xls_file = xlrd.open_workbook(excel_file_path)

# Build in package
import xml.etree.cElementTree as ET

# Specify the path to store the xml file (need to be changed if to create new document)
output_file_path = r"C:/Users/gnt5/Documents/WebFF/XMLdata/FF_Class_I_24May17.xml"

# Create the file root
root = ET.Element("FF-Class-I")

# %% [markdown]
# # Metadata-Header

# %%
# Read the 1st sheet by index
xls_sheet = xls_file.sheet_by_index(0)

sheet = ET.SubElement(root, "Force-Field-Header")

field1 = ET.SubElement(sheet, "Protocol").text = xls_sheet.row_values(2)[1]
field2 = ET.SubElement(sheet, "Name").text = xls_sheet.row_values(3)[1]
field1 = ET.SubElement(sheet, "Description").text = xls_sheet.row_values(4)[1]
field2 = ET.SubElement(sheet, "DOI").text = xls_sheet.row_values(6)[1]
field1 = ET.SubElement(sheet, "URL").text = xls_sheet.row_values(7)[1]
field2 = ET.SubElement(sheet, "NOTES").text = xls_sheet.row_values(8)[1]
field1 = ET.SubElement(sheet, "Affiliation").text = xls_sheet.row_values(10)[1]
field2 = ET.SubElement(sheet, "Scribe").text = xls_sheet.row_values(11)[1]

# %% [markdown]
# # Metadata-Keywords

# %%
# Read the 2nd sheet by index
xls_sheet = xls_file.sheet_by_index(1)

sheet = ET.SubElement(root, "Force-Field-Header")

# Row 2 is the header
xls_sheet_header = map(str, xls_sheet.row_values(2))

for row_num in xrange(3, xls_sheet.nrows):
    for col_num, cell_value in enumerate(xls_sheet.row_values(row_num)):
        ET.SubElement(sheet, xls_sheet_header[col_num]).text = str(cell_value)

# %% [markdown]
# # BondPotential-Harmonic

# %%
# Read the 3rd sheet by index
xls_sheet = xls_file.sheet_by_index(2)

AA=xls_sheet.row_values(2)[1]
BB=xls_sheet.row_values(3)[1]
CC=xls_sheet.row_values(4)[1]
DD=xls_sheet.row_values(5)[1]

sheet = ET.SubElement(root, "BondPotential-Harmonic", {'Style':AA, 'Formula':BB, 'K-units':CC, 'R0-units':DD})

# Row 7 is the header
xls_sheet_header = map(str, xls_sheet.row_values(7))

for row_num in xrange(8, xls_sheet.nrows):
    attribute_idx = xls_sheet_header.index("Comments")
    cur_entry = ET.SubElement(sheet, "Bond", comment=xls_sheet.row_values(row_num)[attribute_idx])
    for col_num, cell_value in enumerate(xls_sheet.row_values(row_num)):
        if col_num == attribute_idx:
            continue
        ET.SubElement(cur_entry, xls_sheet_header[col_num]).text = str(cell_value)

# %% [markdown]
# # AnglePotential-Harmonic

# %%
# Read the 4th sheet by index
xls_sheet = xls_file.sheet_by_index(3)

AA=xls_sheet.row_values(2)[1]
BB=xls_sheet.row_values(3)[1]
CC=xls_sheet.row_values(4)[1]
DD=xls_sheet.row_values(5)[1]

sheet = ET.SubElement(root, "AnglePotential-Harmonic", {'Style':AA, 'Formula':BB, 'Ka-units':CC, 'Theta0-units':DD})

# Row 7 is the header
xls_sheet_header = map(str, xls_sheet.row_values(7))
        
for row_num in xrange(8, xls_sheet.nrows):
    attribute_idx1 = xls_sheet_header.index("Version")
    attribute_idx2 = xls_sheet_header.index("Precedence")
    attribute_idx3 = xls_sheet_header.index("Comments")
    cur_entry = ET.SubElement(sheet, "Angle", version=str(xls_sheet.row_values(row_num)[attribute_idx1]),
                             precedence=str(int(xls_sheet.row_values(row_num)[attribute_idx2])),
                             comment=str(xls_sheet.row_values(row_num)[attribute_idx3]))
    for col_num, cell_value in enumerate(xls_sheet.row_values(row_num)):
        if col_num == attribute_idx1:
            continue
        elif col_num == attribute_idx2:
            continue
        elif col_num == attribute_idx3:
            continue
        ET.SubElement(cur_entry, xls_sheet_header[col_num]).text = str(cell_value)

# %% [markdown]
# # AnglePotential-COS2

# %%
# Read the 5th sheet by index
xls_sheet = xls_file.sheet_by_index(4)

AA=xls_sheet.row_values(2)[1]
BB=xls_sheet.row_values(3)[1]
CC=xls_sheet.row_values(4)[1]
DD=xls_sheet.row_values(5)[1]

sheet = ET.SubElement(root, "AnglePotential-COS2", {'Style':AA, 'Formula':BB, 'Ka-units':CC, 'Theta0-units':DD})

# Row 7 is the header
xls_sheet_header = map(str, xls_sheet.row_values(7))

for row_num in xrange(8, xls_sheet.nrows):
    attribute_idx1 = xls_sheet_header.index("Version")
    attribute_idx2 = xls_sheet_header.index("Precedence")
    attribute_idx3 = xls_sheet_header.index("Comments")
    cur_entry = ET.SubElement(sheet, "Angle", version=str(xls_sheet.row_values(row_num)[attribute_idx1]),
                             precedence=str(int(xls_sheet.row_values(row_num)[attribute_idx2])),
                             comment=str(xls_sheet.row_values(row_num)[attribute_idx3]))
    for col_num, cell_value in enumerate(xls_sheet.row_values(row_num)):
        if col_num == attribute_idx1:
            continue
        elif col_num == attribute_idx2:
            continue
        elif col_num == attribute_idx3:
            continue
        ET.SubElement(cur_entry, xls_sheet_header[col_num]).text = str(cell_value)

# %% [markdown]
# # AnglePotential-CHARMM

# %%
# Read the 6th sheet by index
xls_sheet = xls_file.sheet_by_index(5)

AA=xls_sheet.row_values(2)[1]
BB=xls_sheet.row_values(3)[1]
CC=xls_sheet.row_values(4)[1]
DD=xls_sheet.row_values(5)[1]
EE=xls_sheet.row_values(6)[1]
FF=xls_sheet.row_values(7)[1]

sheet = ET.SubElement(root, "AnglePotential-CHAMRMM", {'Style':AA, 'Formula':BB, 'Ka-units':CC, 'R0-units':DD, 'Kub-units':EE, 
                                                       'Rub-units':FF})

# Row 9 is the header
xls_sheet_header = map(str, xls_sheet.row_values(9))

for row_num in xrange(10, xls_sheet.nrows):
    attribute_idx1 = xls_sheet_header.index("Version")
    attribute_idx2 = xls_sheet_header.index("Precedence")
    attribute_idx3 = xls_sheet_header.index("Comments")
    cur_entry = ET.SubElement(sheet, "Angle", version=str(xls_sheet.row_values(row_num)[attribute_idx1]),
                             precedence=str(int(xls_sheet.row_values(row_num)[attribute_idx2])),
                             comment=str(xls_sheet.row_values(row_num)[attribute_idx3]))
    for col_num, cell_value in enumerate(xls_sheet.row_values(row_num)):
        if col_num == attribute_idx1:
            continue
        elif col_num == attribute_idx2:
            continue
        elif col_num == attribute_idx3:
            continue
        ET.SubElement(cur_entry, xls_sheet_header[col_num]).text = str(cell_value)

# %% [markdown]
# # DihedralPotential-CHARMM

# %%
# Read the 7th sheet by index
xls_sheet = xls_file.sheet_by_index(6)

AA=xls_sheet.row_values(2)[1]
BB=xls_sheet.row_values(3)[1]
CC=xls_sheet.row_values(4)[1]
DD=xls_sheet.row_values(5)[1]
EE=xls_sheet.row_values(6)[1]

sheet = ET.SubElement(root, "DihedralPotential-CHARMM", {'Style':AA, 'Formula':BB, 'Convention':CC, 'Kd-units':DD, 
                                                         'Phi0-units':EE})

# Row 8 is the header
xls_sheet_header = map(str, xls_sheet.row_values(8))

for row_num in xrange(9, xls_sheet.nrows):
    attribute_idx1 = xls_sheet_header.index("Version")
    attribute_idx2 = xls_sheet_header.index("Comments")
    cur_entry = ET.SubElement(sheet, "Dihedral", version=str(xls_sheet.row_values(row_num)[attribute_idx1]),
                             comment=str(xls_sheet.row_values(row_num)[attribute_idx2]))
    for col_num, cell_value in enumerate(xls_sheet.row_values(row_num)):
        if col_num == attribute_idx1:
            continue
        elif col_num == attribute_idx2:
            continue
        ET.SubElement(cur_entry, xls_sheet_header[col_num]).text = str(cell_value)

# %% [markdown]
# # DihedralPotential-Harmonic

# %%
# Read the 8th sheet by index
xls_sheet = xls_file.sheet_by_index(7)

AA=xls_sheet.row_values(2)[1]
BB=xls_sheet.row_values(3)[1]
CC=xls_sheet.row_values(4)[1]
DD=xls_sheet.row_values(5)[1]

sheet = ET.SubElement(root, "DihedralPotential-Harmonic", {'Style':AA, 'Formula':BB, 'Convention':CC, 'Kd-units':DD})

# Row 7 is the header
xls_sheet_header = map(str, xls_sheet.row_values(7))

for row_num in xrange(8, xls_sheet.nrows):
    attribute_idx1 = xls_sheet_header.index("Version")
    attribute_idx2 = xls_sheet_header.index("Comments")
    cur_entry = ET.SubElement(sheet, "Dihedral", version=str(xls_sheet.row_values(row_num)[attribute_idx1]),
                             comment=str(xls_sheet.row_values(row_num)[attribute_idx2]))
    for col_num, cell_value in enumerate(xls_sheet.row_values(row_num)):
        if col_num == attribute_idx1:
            continue
        elif col_num == attribute_idx2:
            continue
        ET.SubElement(cur_entry, xls_sheet_header[col_num]).text = str(cell_value)

# %% [markdown]
# # DihedralPotential-Quadratic

# %%
# Read the 9th sheet by index
xls_sheet = xls_file.sheet_by_index(8)

AA=xls_sheet.row_values(2)[1]
BB=xls_sheet.row_values(3)[1]
CC=xls_sheet.row_values(4)[1]
DD=xls_sheet.row_values(5)[1]
EE=xls_sheet.row_values(6)[1]

sheet = ET.SubElement(root, "DihedralPotential-Quadratic", {'Style':AA, 'Formula':BB, 'Convention':CC, 'Kd-units':DD, 
                                                            'Phi0-units':EE})

# Row 8 is the header
xls_sheet_header = map(str, xls_sheet.row_values(8))

for row_num in xrange(9, xls_sheet.nrows):
    attribute_idx1 = xls_sheet_header.index("Version")
    attribute_idx2 = xls_sheet_header.index("Comments")
    cur_entry = ET.SubElement(sheet, "Dihedral", version=str(xls_sheet.row_values(row_num)[attribute_idx1]),
                             comment=str(xls_sheet.row_values(row_num)[attribute_idx2]))
    for col_num, cell_value in enumerate(xls_sheet.row_values(row_num)):
        if col_num == attribute_idx1:
            continue
        elif col_num == attribute_idx2:
            continue
        ET.SubElement(cur_entry, xls_sheet_header[col_num]).text = str(cell_value)

# %% [markdown]
# # DihedralPotential-OPLS

# %%
# Read the 10th sheet by index
xls_sheet = xls_file.sheet_by_index(9)

AA=xls_sheet.row_values(2)[1]
BB=xls_sheet.row_values(3)[1]
CC=xls_sheet.row_values(4)[1]
DD=xls_sheet.row_values(5)[1]

sheet = ET.SubElement(root, "DihedralPotential-OPLS", {'Style':AA, 'Formula':BB, 'Convention':CC, 'Kd-units':DD})

# Row 7 is the header
xls_sheet_header = map(str, xls_sheet.row_values(7))

for row_num in xrange(8, xls_sheet.nrows):
    attribute_idx1 = xls_sheet_header.index("Version")
    attribute_idx2 = xls_sheet_header.index("Comments")
    cur_entry = ET.SubElement(sheet, "Dihedral", version=str(xls_sheet.row_values(row_num)[attribute_idx1]),
                             comment=str(xls_sheet.row_values(row_num)[attribute_idx2]))
    for col_num, cell_value in enumerate(xls_sheet.row_values(row_num)):
        if col_num == attribute_idx1:
            continue
        elif col_num == attribute_idx2:
            continue
        ET.SubElement(cur_entry, xls_sheet_header[col_num]).text = str(cell_value)

# %% [markdown]
# # DihedralPotential-FourierSimple

# %%
# Read the 11th sheet by index
xls_sheet = xls_file.sheet_by_index(10)

AA=xls_sheet.row_values(2)[1]
BB=xls_sheet.row_values(3)[1]
CC=xls_sheet.row_values(4)[1]
DD=xls_sheet.row_values(5)[1]

sheet = ET.SubElement(root, "DihedralPotential-FourierSimple", {'Style':AA, 'Formula':BB, 'Convention':CC, 'Kd-units':DD})

# Row 7 is the header
xls_sheet_header = map(str, xls_sheet.row_values(7))

for row_num in xrange(8, xls_sheet.nrows):
    attribute_idx1 = xls_sheet_header.index("Version")
    attribute_idx2 = xls_sheet_header.index("Comments")
    cur_entry = ET.SubElement(sheet, "Dihedral", version=str(xls_sheet.row_values(row_num)[attribute_idx1]),
                             comment=str(xls_sheet.row_values(row_num)[attribute_idx2]))
    for col_num, cell_value in enumerate(xls_sheet.row_values(row_num)):
        if col_num == attribute_idx1:
            continue
        elif col_num == attribute_idx2:
            continue
        ET.SubElement(cur_entry, xls_sheet_header[col_num]).text = str(cell_value)

# %% [markdown]
# # ImproperPotential-CVFF

# %%
# Read the 12th sheet by index
xls_sheet = xls_file.sheet_by_index(11)

AA=xls_sheet.row_values(2)[1]
BB=xls_sheet.row_values(3)[1]
CC=xls_sheet.row_values(4)[1]
DD=xls_sheet.row_values(5)[1]

sheet = ET.SubElement(root, "ImproperPotential-CVFF", {'Style':AA, 'Formula':BB, 'Convention':CC, 'Ki-units':DD})

# Row 7 is the header
xls_sheet_header = map(str, xls_sheet.row_values(7))

for row_num in xrange(8, xls_sheet.nrows):
    attribute_idx1 = xls_sheet_header.index("Version")
    attribute_idx2 = xls_sheet_header.index("Comments")
    cur_entry = ET.SubElement(sheet, "Improper", version=str(xls_sheet.row_values(row_num)[attribute_idx1]),
                             comment=str(xls_sheet.row_values(row_num)[attribute_idx2]))
    for col_num, cell_value in enumerate(xls_sheet.row_values(row_num)):
        if col_num == attribute_idx1:
            continue
        elif col_num == attribute_idx2:
            continue
        ET.SubElement(cur_entry, xls_sheet_header[col_num]).text = str(cell_value)

# %% [markdown]
# # ImproperPotential-COS2

# %%
# Read the 13th sheet by index
xls_sheet = xls_file.sheet_by_index(12)

AA=xls_sheet.row_values(2)[1]
BB=xls_sheet.row_values(3)[1]
CC=xls_sheet.row_values(4)[1]
DD=xls_sheet.row_values(5)[1]
EE=xls_sheet.row_values(6)[1]

sheet = ET.SubElement(root, "ImproperPotential-COS2", {'Style':AA, 'Formula':BB, 'Convention':CC, 'Ki-units':DD, 'Chi0-units':EE})

# Row 8 is the header
xls_sheet_header = map(str, xls_sheet.row_values(8))

for row_num in xrange(9, xls_sheet.nrows):
    attribute_idx1 = xls_sheet_header.index("Version")
    attribute_idx2 = xls_sheet_header.index("Comments")
    cur_entry = ET.SubElement(sheet, "Improper", version=str(xls_sheet.row_values(row_num)[attribute_idx1]),
                             comment=str(xls_sheet.row_values(row_num)[attribute_idx2]))
    for col_num, cell_value in enumerate(xls_sheet.row_values(row_num)):
        if col_num == attribute_idx1:
            continue
        elif col_num == attribute_idx2:
            continue
        ET.SubElement(cur_entry, xls_sheet_header[col_num]).text = str(cell_value)

# %% [markdown]
# # ImproperPotential-Harmonic

# %%
# Read the 14th sheet by index
xls_sheet = xls_file.sheet_by_index(13)

AA=xls_sheet.row_values(2)[1]
BB=xls_sheet.row_values(3)[1]
CC=xls_sheet.row_values(4)[1]
DD=xls_sheet.row_values(5)[1]
EE=xls_sheet.row_values(6)[1]

sheet = ET.SubElement(root, "ImproperPotential-Harmonic", {'Style':AA, 'Formula':BB, 'Convention':CC, 'Ki-units':DD, 'Chi0-units':EE})

# Row 8 is the header
xls_sheet_header = map(str, xls_sheet.row_values(8))

for row_num in xrange(9, xls_sheet.nrows):
    attribute_idx1 = xls_sheet_header.index("Version")
    attribute_idx2 = xls_sheet_header.index("Comments")
    cur_entry = ET.SubElement(sheet, "Improper", version=str(xls_sheet.row_values(row_num)[attribute_idx1]),
                             comment=str(xls_sheet.row_values(row_num)[attribute_idx2]))
    for col_num, cell_value in enumerate(xls_sheet.row_values(row_num)):
        if col_num == attribute_idx1:
            continue
        elif col_num == attribute_idx2:
            continue
        ET.SubElement(cur_entry, xls_sheet_header[col_num]).text = str(cell_value)

# %% [markdown]
# # ImproperPotential-Fourier

# %%
# Read the 15th sheet by index
xls_sheet = xls_file.sheet_by_index(14)

AA=xls_sheet.row_values(2)[1]
BB=xls_sheet.row_values(3)[1]
CC=xls_sheet.row_values(4)[1]
DD=xls_sheet.row_values(5)[1]

sheet = ET.SubElement(root, "ImproperPotential-Fourier", {'Style':AA, 'Formula':BB, 'Convention':CC, 'Kd-units':DD})

# Row 7 is the header
xls_sheet_header = map(str, xls_sheet.row_values(7))

for row_num in xrange(8, xls_sheet.nrows):
    attribute_idx1 = xls_sheet_header.index("Version")
    attribute_idx2 = xls_sheet_header.index("Comments")
    cur_entry = ET.SubElement(sheet, "Improper", version=str(xls_sheet.row_values(row_num)[attribute_idx1]),
                             comment=str(xls_sheet.row_values(row_num)[attribute_idx2]))
    for col_num, cell_value in enumerate(xls_sheet.row_values(row_num)):
        if col_num == attribute_idx1:
            continue
        elif col_num == attribute_idx2:
            continue
        ET.SubElement(cur_entry, xls_sheet_header[col_num]).text = str(cell_value)

# %% [markdown]
# # ImproperPotential-Umbrella

# %%
# Read the 16th sheet by index
xls_sheet = xls_file.sheet_by_index(15)

AA=xls_sheet.row_values(2)[1]
BB=xls_sheet.row_values(3)[1]
CC=xls_sheet.row_values(4)[1]
DD=xls_sheet.row_values(5)[1]
EE=xls_sheet.row_values(6)[1]

sheet = ET.SubElement(root, "ImproperPotential-Umbrella", {'Style':AA, 'Formula':BB, 'Convention':CC, 'Ki-units':DD, 'w0-units':EE})

# Row 8 is the header
xls_sheet_header = map(str, xls_sheet.row_values(8))

for row_num in xrange(9, xls_sheet.nrows):
    attribute_idx1 = xls_sheet_header.index("Version")
    attribute_idx2 = xls_sheet_header.index("Comments")
    cur_entry = ET.SubElement(sheet, "Improper", version=str(xls_sheet.row_values(row_num)[attribute_idx1]),
                             comment=str(xls_sheet.row_values(row_num)[attribute_idx2]))
    for col_num, cell_value in enumerate(xls_sheet.row_values(row_num)):
        if col_num == attribute_idx1:
            continue
        elif col_num == attribute_idx2:
            continue
        ET.SubElement(cur_entry, xls_sheet_header[col_num]).text = str(cell_value)

# %% [markdown]
# # NonBonded-LJ

# %%
# Read the 17th sheet by index
xls_sheet = xls_file.sheet_by_index(16)

AA=xls_sheet.row_values(2)[1]
BB=xls_sheet.row_values(3)[1]
CC=xls_sheet.row_values(4)[1]
DD=xls_sheet.row_values(5)[1]
EE=xls_sheet.row_values(6)[1]

sheet = ET.SubElement(root, "NonBonded-LJ", {'Style':AA, 'Formula':BB, 'epsilon-units':CC, 'sigma-units':DD, 'Combining-Rules':EE})

# Row 8 is the header
xls_sheet_header = map(str, xls_sheet.row_values(8))

for row_num in xrange(9, xls_sheet.nrows):
    attribute_idx1 = xls_sheet_header.index("Comments")
    cur_entry = ET.SubElement(sheet, "NonBonded", comment=str(xls_sheet.row_values(row_num)[attribute_idx1]))
    for col_num, cell_value in enumerate(xls_sheet.row_values(row_num)):
        if col_num == attribute_idx1:
            continue
        ET.SubElement(cur_entry, xls_sheet_header[col_num]).text = str(cell_value)

# %% [markdown]
# # NonBonded-LJ (Rmin)

# %%
# Read the 18th sheet by index
xls_sheet = xls_file.sheet_by_index(17)

AA=xls_sheet.row_values(2)[1]
BB=xls_sheet.row_values(3)[1]
CC=xls_sheet.row_values(4)[1]
DD=xls_sheet.row_values(5)[1]
EE=xls_sheet.row_values(6)[1]

sheet = ET.SubElement(root, "NonBonded-LJ-Rmin", {'Style':AA, 'Formula':BB, 'epsilon-units':CC, 'Rmin-units':DD, 'Combining-Rules':EE})

# Row 8 is the header
xls_sheet_header = map(str, xls_sheet.row_values(8))

for row_num in xrange(9, xls_sheet.nrows):
    attribute_idx1 = xls_sheet_header.index("Comments")
    cur_entry = ET.SubElement(sheet, "NonBonded", comment=str(xls_sheet.row_values(row_num)[attribute_idx1]))
    for col_num, cell_value in enumerate(xls_sheet.row_values(row_num)):
        if col_num == attribute_idx1:
            continue
        ET.SubElement(cur_entry, xls_sheet_header[col_num]).text = str(cell_value)

# %% [markdown]
# # NonBonded-LJ (AB)

# %%
# Read the 19th sheet by index
xls_sheet = xls_file.sheet_by_index(18)

AA=xls_sheet.row_values(2)[1]
BB=xls_sheet.row_values(3)[1]
CC=xls_sheet.row_values(4)[1]
DD=xls_sheet.row_values(5)[1]
EE=xls_sheet.row_values(6)[1]

sheet = ET.SubElement(root, "NonBonded-LJ-AB", {'Style':AA, 'Formula':BB, 'epsilon-units':CC, 'Rmin-units':DD, 'Combining-Rules':EE})

# Row 8 is the header
xls_sheet_header = map(str, xls_sheet.row_values(8))

for row_num in xrange(9, xls_sheet.nrows):
    attribute_idx1 = xls_sheet_header.index("Comments")
    cur_entry = ET.SubElement(sheet, "NonBonded", comment=str(xls_sheet.row_values(row_num)[attribute_idx1]))
    for col_num, cell_value in enumerate(xls_sheet.row_values(row_num)):
        if col_num == attribute_idx1:
            continue
        ET.SubElement(cur_entry, xls_sheet_header[col_num]).text = str(cell_value)

# %% [markdown]
# # NonBonded-LJ (Class 2)

# %%
# Read the 20th sheet by index
xls_sheet = xls_file.sheet_by_index(19)

AA=xls_sheet.row_values(2)[1]
BB=xls_sheet.row_values(3)[1]
CC=xls_sheet.row_values(4)[1]
DD=xls_sheet.row_values(5)[1]
EE=xls_sheet.row_values(6)[1]

sheet = ET.SubElement(root, "NonBonded-LJ-Class-2", {'Style':AA, 'Formula':BB, 'epsilon-units':CC, 'Rmin-units':DD, 'Combining-Rules':EE})

# Row 8 is the header
xls_sheet_header = map(str, xls_sheet.row_values(8))

for row_num in xrange(9, xls_sheet.nrows):
    attribute_idx1 = xls_sheet_header.index("Comments")
    cur_entry = ET.SubElement(sheet, "NonBonded", comment=str(xls_sheet.row_values(row_num)[attribute_idx1]))
    for col_num, cell_value in enumerate(xls_sheet.row_values(row_num)):
        if col_num == attribute_idx1:
            continue
        ET.SubElement(cur_entry, xls_sheet_header[col_num]).text = str(cell_value)

# %% [markdown]
# # NonBonded-LJ2

# %%
# Read the 21th sheet by index
xls_sheet = xls_file.sheet_by_index(20)

AA=xls_sheet.row_values(2)[1]
BB=xls_sheet.row_values(3)[1]
CC=xls_sheet.row_values(4)[1]
DD=xls_sheet.row_values(5)[1]
EE=xls_sheet.row_values(6)[1]

sheet = ET.SubElement(root, "NonBonded-LJ2", {'Style':AA, 'Formula':BB, 'epsilon-units':CC, 'Rmin-units':DD, 'Combining-Rules':EE})

# Row 8 is the header
xls_sheet_header = map(str, xls_sheet.row_values(8))

for row_num in xrange(9, xls_sheet.nrows):
    attribute_idx1 = xls_sheet_header.index("Comments")
    cur_entry = ET.SubElement(sheet, "NonBonded", comment=str(xls_sheet.row_values(row_num)[attribute_idx1]))
    for col_num, cell_value in enumerate(xls_sheet.row_values(row_num)):
        if col_num == attribute_idx1:
            continue
        ET.SubElement(cur_entry, xls_sheet_header[col_num]).text = str(cell_value)

# %% [markdown]
# # Equivalence Table

# %%
# Read the 22th sheet by index
xls_sheet = xls_file.sheet_by_index(21)

# Row 4 is the header
xls_sheet_header = map(str, xls_sheet.row_values(4))

for row_num in xrange(5, xls_sheet.nrows):
    attribute_idx1 = xls_sheet_header.index("Version")
    attribute_idx2 = xls_sheet_header.index("Reference")
    cur_entry = ET.SubElement(root, "Equivalence", version=str(xls_sheet.row_values(row_num)[attribute_idx1]),
                             reference=str(xls_sheet.row_values(row_num)[attribute_idx2]))
    for col_num, cell_value in enumerate(xls_sheet.row_values(row_num)):
        if col_num == attribute_idx1:
            continue
        elif col_num == attribute_idx2:
            continue
        ET.SubElement(cur_entry, xls_sheet_header[col_num]).text = str(cell_value)

# %% [markdown]
# # Tree Creation and File Output

# %%
# Create a ElementTree, which is the structure corresponding to the Xml Document
tree = ET.ElementTree(root)

# Write it out
tree.write(output_file_path)

# The following is purely for visualisation within Python/Notebook, rather than open outside
import xml.dom.minidom as xdm
xml = xdm.parse(output_file_path)
print xml.toprettyxml()

# Save into pretty print format
with open(output_file_path, "w") as text_file:
    text_file.write(xml.toprettyxml().encode("UTF-8"))
    text_file.close()
# Out:
# <?xml version="1.0" ?>
# <FF-Class-I>
# 	<Force-Field-Header>
# 		<Protocol>?</Protocol>
# 		<Name>asd</Name>
# 		<Description>dsa</Description>
# 		<DOI>ddd</DOI>
# 		<URL>sss</URL>
# 		<NOTES>aaa</NOTES>
# 		<Affiliation>asdasd</Affiliation>
# 		<Scribe>dsadsa</Scribe>
# 	</Force-Field-Header>
# 	<Force-Field-Header>
# 		<Keywords>General Organic</Keywords>
# 		<Additional-Keywords>asd</Additional-Keywords>
# 		<Keywords>Acids</Keywords>
# 		<Additional-Keywords>dsa</Additional-Keywords>
# 		<Keywords>Alcohols</Keywords>
# 		<Additional-Keywords>aaa</Additional-Keywords>
# 		<Keywords>Alkanes</Keywords>
# 		<Additional-Keywords>sss</Additional-Keywords>
# 		<Keywords>Esters</Keywords>
# 		<Additional-Keywords>ddd</Additional-Keywords>
# 		<Keywords>Ketones</Keywords>
# 		<Additional-Keywords>dsaasd</Additional-Keywords>
# 		<Keywords>?</Keywords>
# 		<Additional-Keywords/>
# 		<Keywords>?</Keywords>
# 		<Additional-Keywords/>
# 		<Keywords>?</Keywords>
# 		<Additional-Keywords/>
# ...
